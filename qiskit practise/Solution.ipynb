# %%
# !pip install qiskit
# !pip install pylatexenc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from qiskit import *
from qiskit.tools.monitor import job_monitor
from qiskit.tools.visualization import plot_state_qsphere
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex

# %% [markdown]
# **Ans.to.the.que.no:1**

# %%
# creating the circuit
circuit = QuantumCircuit(1)
initial_state = [1/2**0.5, 1/2**0.5]
circuit.initialize(initial_state, 0)
# drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)

#Run the simulator and get the result
result = simulator.run(circuit).result()
#Get statevector
final_state = result.get_statevector()

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# **Ans.to.the.que.no:2**

# %%
# Creating the circuit
circuit = QuantumCircuit(3, 1)
# Applying the gate
circuit.h(0)
circuit.sx(1)
circuit.ccx(0, 1, 2)
# Apply the measurement on z basis
circuit.measure(2,0)
# Drawing the circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Select the simulator
simulator = Aer.get_backend('aer_simulator')
# Assigning the job
job = execute(circuit, simulator)
# Get the result from job
result = job.result()
# Get the histogram data
count = result.get_counts(circuit)
plot_histogram(count)

# %%
# Creating the circuit
circuit = QuantumCircuit(3, 1)
# Applying the gate
circuit.ccx(0, 1, 2)
circuit.h(2)
circuit.sx(2)
# Applying the measurement on Y basis
circuit.sdg(2)
circuit.h(2)
circuit.measure(2,0)
# Drawing the circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
# Select the simulator
simulator = Aer.get_backend('aer_simulator')
# Assigning the job
job = execute(circuit, simulator)
# Getthe result from  the job
result = job.result()
# Get histogram data
count = result.get_counts(circuit)
plot_histogram(count)

# %% [markdown]
# **Ans.to.the.que.no:3**

# %%
#Creating the circuit
circuit = QuantumCircuit(3)
#Applying the gate
circuit.ccx(0, 1, 2)
circuit.h(2)
circuit.sx(2)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_unitary()
#Get the statevector
statevec = simulator.run(circuit).result().get_unitary()
array_to_latex(statevec)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0 & 0 & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0 & 0  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0  \\
#  0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0 & 0 & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0 & 0  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0  \\
#  0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
#Creating the circuit
circuit = QuantumCircuit(3, 1)
#Applying the gate
circuit.ccx(0, 1, 2)
circuit.h(2)
circuit.sx(2)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state=True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_unitary()
#Get the statevector
statevec = simulator.run(circuit).result().get_unitary()
array_to_latex(statevec)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0 & 0 & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0 & 0  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0  \\
#  0 & 0 & 0 & \frac{\sqrt{2} i}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0 & 0 & 0  \\
#  0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0 & 0  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & 0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0  \\
#  0 & 0 & 0 & - \frac{\sqrt{2} i}{2} & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# **Ans.to.the.que.no:4**

# %%
#Creating an entanglement circuit with H, CX gate
circuit = QuantumCircuit(2, 2)
#Applying the hadamard gate
circuit.h(0) 
circuit.cx(0, 1)
#Applying the measurement
circuit.measure(0,0)
circuit.measure(1,1)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Run on the simulator 
#Select a simulator
simulator = Aer.get_backend('aer_simulator')
job = execute(circuit, simulator)
result = job.result()
counts=result.get_counts(circuit)
plot_histogram(counts)

# %% [markdown]
# **run on the real quantum device**

# %%
#Creating an entanglement circuit with H, CX gate and apply measurement
circuit = QuantumCircuit(2, 2)
#Applying the hadamard gate to create entanglement
circuit.h(0) 
circuit.cx(0, 1)
#Applying the measurement
circuit.measure(0,0)
circuit.measure(1,1)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Import library for QC
from qiskit import IBMQ
#Save API token
IBMQ.save_account('a089a36a8f1a09f4f83b889437e0cc6b2c8721673e25e20dcb1fc6d620d09861e9f8ca8c92c112964858e4aaa0b726392d7a4c9cac037cd33995f28e6a16cc21')
#Load account
IBMQ.load_account()
#Select the provider
provider = IBMQ.get_provider('ibm-q')
#Select the quantum device
qcomp = provider.get_backend('ibmq_belem')
#Run on real device
job = execute(circuit, backend = qcomp)
job_monitor(job)
result = job.result()
#Get the histogram data
count = result.get_counts()
# Out:
# <ipython-input-19-6b29758cff41>:4: DeprecationWarning: The package qiskit.providers.ibmq is being deprecated. Please see https://ibm.biz/provider_migration_guide to get instructions on how to migrate to qiskit-ibm-provider (https://github.com/Qiskit/qiskit-ibm-provider) and qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   IBMQ.save_account('a089a36a8f1a09f4f83b889437e0cc6b2c8721673e25e20dcb1fc6d620d09861e9f8ca8c92c112964858e4aaa0b726392d7a4c9cac037cd33995f28e6a16cc21')
# <ipython-input-19-6b29758cff41>:4: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
# ...

# %%
#Visualize the result after measurement
plot_histogram(count)

# %% [markdown]
# **Ans.to.the.que.no:5**

# %% [markdown]
# **(a) initialize a state in X basis and measure in X,Y and Z basis**

# %%
#Creating the circuit
circuit = QuantumCircuit(1, 1)
#Initialize the circuit
circuit.y(0)
#'x'basis measurement
circuit.h(0)
#Applying the measurement
circuit.measure(0,0) 
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %%
#Creating the circuit
circuit = QuantumCircuit(1, 1)
#Initialize
circuit.h(0)
circuit.y(0)
#Applying the measurement in y basis
circuit.sdg(0)
circuit.h(0)
circuit.measure(0,0)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %%
#Creating the circuit
circuit = QuantumCircuit(1, 1)
#initialize
circuit.h(0)
circuit.y(0)
#'Z' basis measurement
#Applying the measurement
circuit.measure(0,0)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# **(b) initialize a state in Y basis and measure in X, Y and Z basis.**

# %%
#Creating the circuit
circuit = QuantumCircuit(1,1)
#Initialize
circuit.sx(0)
#Applying the measurement in y basis
circuit.sdg(0)
circuit.h(0)
circuit.measure(0,0)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %%
#Creating the circuit
circuit = QuantumCircuit(1,1)
#Initialize
circuit.sx(0)
#'X' basis measurement so applying the haramard gate
circuit.h(0)
#Applying the measurement
circuit.measure(0,0) 
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %%
#Creating the circuit
circuit = QuantumCircuit(1,1)
#Initialize
circuit.sx(0)
#Apply z basis on measurement
circuit.measure(0,0)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# **(c) initialize a state in Z basis and measure in X, Y and Z basis.**

# %%
#Creating the circuit
circuit = QuantumCircuit(1, 1)
#'Z'basis measurement
#Applying the measurement
circuit.measure(0,0) 
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %%
#Creating the circuit
circuit = QuantumCircuit(1, 1)
#'X'basis measurement
#Applying the hadamard gate 
circuit.h(0)
#Applying the measurement
circuit.measure(0,0) 
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %%
#Creating the circuit
circuit = QuantumCircuit(1, 1)
#Applying the measurement in y basis
circuit.sdg(0)
circuit.h(0)
circuit.measure(0,0)
#Drawing the circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
#Select the simulator
simulator = Aer.get_backend('aer_simulator')
#Save the statevector
circuit.save_statevector()
#Assemble the circuit
qobj = assemble(circuit)
#Run on simulator and get the result
result = simulator.run(circuit).result()
#Get the statevector
final_state = result.get_statevector()
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)
